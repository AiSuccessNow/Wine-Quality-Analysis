# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
red_wine_df = pd.read_csv('/Users/ivanvargas/Documents/AI_Bootcamp/Wine-Quality-Analysis/wine_quality_red.csv', delimiter=';')
white_wine_df = pd.read_csv('/Users/ivanvargas/Documents/AI_Bootcamp/Wine-Quality-Analysis/wine_quality_white.csv', delimiter=';')

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
red_wine_df['color'] = 'red'

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality color
# 0         9.4        5   red
# 1         9.8        5   red
# 2         9.8        5   red
# 3         9.8        6   red
# 4         9.4        5   red
# ...       ...      ...   ...
# 1594     10.5        5   red
# 1595     11.2        6   red
# 1596     11.0        6   red
# 1597     10.2        5   red
# 1598     11.0        6   red
#
# [1599 rows x 13 columns]

# %%
red_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  color                 1599 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %%
red_wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
white_wine_df['color'] = 'white'

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         8.8        6  white
# 1         9.5        6  white
# 2        10.1        6  white
# 3         9.9        6  white
# 4         9.9        6  white
# ...       ...      ...    ...
# 4893     11.2        6  white
# 4894      9.6        5  white
# 4895      9.4        6  white
# 4896     12.8        7  white
# 4897     11.8        6  white
#
# [4898 rows x 13 columns]

# %%
white_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  color                 4898 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 497.6+ KB

# %%
white_wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
combined_wine_df = pd.concat([red_wine_df, white_wine_df], ignore_index=True, sort=False)

combined_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %%
combined_wine_df = combined_wine_df.sort_values(by=['quality'], ascending=False)

combined_wine_df.head(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2475            6.9             0.360         0.34            4.20      0.018
# 3204            7.1             0.260         0.49            2.20      0.032
# 2426            7.4             0.240         0.36            2.00      0.031
# 2373            9.1             0.270         0.45           10.60      0.035
# 2419            6.6             0.360         0.29            1.60      0.021
# 5531            6.9             0.220         0.28            7.80      0.050
# 2694            5.3             0.240         0.33            1.30      0.033
# 2685            5.2             0.240         0.45            3.80      0.027
# 1090           10.0             0.260         0.54            1.90      0.083
# 2686            7.0             0.240         0.32            1.30      0.037
# 5766            6.3             0.170         0.32            1.00      0.040
# 2817            7.2             0.260         0.44            7.10      0.027
# 4862            6.5             0.260         0.31            3.60      0.030
# 2815            8.2             0.370         0.36            1.00      0.034
# 6386            3.9             0.225         0.40            4.20      0.030
# 6385            4.4             0.320         0.39            4.30      0.030
# 4977            6.1             0.280         0.27            4.70      0.030
# 2818            8.2             0.370         0.36            1.00      0.034
# 3314            6.5             0.180         0.34            1.60      0.040
# 3378            6.4             0.150         0.36            1.80      0.034
# 4456            6.6             0.290         0.31            3.90      0.027
# 2036            6.6             0.160         0.32            1.40      0.035
# 5280            7.0             0.220         0.26            9.20      0.027
# 3983            6.9             0.150         0.28            4.40      0.029
# 3377            6.4             0.150         0.36            1.80      0.034
# 4985            6.1             0.280         0.27            4.70      0.030
# 3981            6.9             0.150         0.28            4.40      0.029
# 1120            7.9             0.540         0.34            2.50      0.076
# 3897            6.3             0.410         0.18            3.50      0.027
# 588             5.0             0.420         0.24            2.00      0.060
# 2705            5.2             0.240         0.45            3.80      0.027
# 4668            7.0             0.530         0.43            6.10      0.029
# 5048            6.6             0.150         0.32            6.00      0.033
# 4352            5.8             0.315         0.27            1.55      0.026
# 4489            5.2             0.285         0.29            5.15      0.035
# 2935            7.8             0.290         0.36            7.00      0.042
# 1854            6.7             0.260         0.39            1.10      0.040
# 1061                  7.0                  16.0  0.99462  3.21       0.69
# 3005                 12.0                  90.0  0.99440  3.01       0.38
# 3002                 29.0                 128.0  0.99370  3.34       0.64
# 6401                 24.0                 125.0  0.98986  3.36       0.33
# 3001                 31.0                 122.0  0.99400  3.30       0.50
#
#       alcohol  quality  color
# 2475     12.7        9  white
# 3204     12.9        9  white
# 2426     12.5        9  white
# 2373     10.4        9  white
# 2419     12.4        9  white
# 5531     11.5        8  white
# 2694     11.0        8  white
# 2685     11.2        8  white
# 1090     11.8        8    red
# 2686     11.2        8  white
# 5766     13.1        8  white
# 2817     11.1        8  white
# 4862     12.6        8  white
# 2815     11.7        8  white
# 6386     12.8        8  white
# 6385     12.8        8  white
# 4977     12.5        8  white
# 2818     11.7        8  white
# 3314     11.5        8  white
# 3378     11.0        8  white
# 4456     12.6        8  white
# 2036     12.4        8  white
# 5280     12.5        8  white
# 3983     10.4        8  white
# 3377     11.0        8  white
# 4985     12.5        8  white
# 3981     10.4        8  white
# 1120     13.1        8    red
# 3897     12.8        8  white
# 588      14.0        8    red
# 2705     11.2        8  white
# 4668     12.5        8  white
# 5048     12.1        8  white
# 4352     11.9        8  white
# 4489     12.4        8  white
# 2935     11.2        8  white
# 1854      9.6        8  white
# 4628     12.0        8  white
# 1269     14.0        8    red
# 267      12.8        8    red
# 5044     12.1        8  white
# 3989     10.7        8  white
# 4629     12.0        8  white
# 3011     12.3        8  white
# 3988     12.0        8  white
# 1061     12.5        8    red
# 3005     10.5        8  white
# 3002     10.9        8  white
# 6401     12.8        8  white
# 3001     11.1        8  white

# %%
combined_wine_df.nunique()
# Out:
# fixed acidity           106
# volatile acidity        187
# citric acid              89
# residual sugar          316
# chlorides               214
# free sulfur dioxide     135
# total sulfur dioxide    276
# density                 998
# pH                      108
# sulphates               111
# alcohol                 111
# quality                   7
# color                     2
# dtype: int64

# %%
duplicates = combined_wine_df.duplicated().sum()

print(f'Number of duplicate rows before removal:{duplicates}')
# Out:
# Number of duplicate rows before removal:1177

# %%
combined_wine_df.to_csv('cleaned_wine_data.csv', index=False)

# %%
plt.figure(figsize=(12, 6))
for quality in sorted(red_wine_df['quality'].unique()):
    subset = red_wine_df[red_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by Red Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
for quality in sorted(white_wine_df['quality'].unique()):
    subset = white_wine_df[white_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by White Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
for quality in sorted(combined_wine_df['quality'].unique()):
    subset = combined_wine_df[combined_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
red_wine_df.groupby('quality')['sulphates'].mean().plot(color='red')
plt.title('Average Sulphates by Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
white_wine_df.groupby('quality')['sulphates'].mean().plot(color='blue')
plt.title('Average Sulphates by White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
combined_wine_df.groupby('quality')['sulphates'].mean().plot(color='purple')
plt.title('Average Sulphates by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
red_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='red')
plt.title('Average Volatile Acidity by Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
white_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='blue')
plt.title('Average Volatile Acidity by White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
combined_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='purple')
plt.title('Average Volatile Acidity by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
red_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='red')
plt.title('Average Chlorides by Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
white_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='blue')
plt.title('Average Chlorides by White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
combined_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='purple')
plt.title('Average Chlorides by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 4))
for quality in sorted(red_wine_df['quality'].unique()):
    subset = red_wine_df[red_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Red Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 4))
for quality in sorted(white_wine_df['quality'].unique()):
    subset = white_wine_df[white_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 4))
for quality in sorted(combined_wine_df['quality'].unique()):
    subset = combined_wine_df[combined_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
combined_wine_df.boxplot(column='quality', by='color')
plt.title('Box Plot of Wine Quality by Wine Color')
plt.suptitle('')
plt.xlabel('Wine Color')
plt.ylabel('Quality')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(red_wine_df['residual sugar'], red_wine_df['quality'], alpha=0.5, c='red')
plt.title('Residual Sugar vs. Red Wine Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(white_wine_df['residual sugar'], white_wine_df['quality'], alpha=0.5, c='blue')
plt.title('Residual Sugar vs. White Wine Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(combined_wine_df['residual sugar'], combined_wine_df['quality'], alpha=0.5, c='purple')
plt.title('Residual Sugar vs. Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(red_wine_df['density'], red_wine_df['alcohol'], alpha=0.5, c='red')
plt.title('Relationship between Density and Alcohol Content in Red Wine')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(white_wine_df['density'], white_wine_df['alcohol'], alpha=0.5, c='blue')
plt.title('Relationship between Density and Alcohol Content in White Wine')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(combined_wine_df['density'], combined_wine_df['alcohol'], alpha=0.5, c='purple')
plt.title('Relationship between Density and Alcohol Content')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %%
chemical_properties = combined_wine_df.drop(columns=['color'])

# %%
wine_correlation = chemical_properties.corr()

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wine_correlation, cmap='coolwarm', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(wine_correlation)), wine_correlation.columns, rotation=90)
plt.yticks(range(len(wine_correlation)), wine_correlation.columns)
plt.title('Correlation Heatmap of Wine Chemical Properties')
plt.show()
