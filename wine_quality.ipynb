# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load red wine and white wine datasets
red_wine_df = pd.read_csv('/Users/ivanvargas/Documents/AI_Bootcamp/Wine-Quality-Analysis/wine_quality_red.csv', delimiter=';')
white_wine_df = pd.read_csv('/Users/ivanvargas/Documents/AI_Bootcamp/Wine-Quality-Analysis/wine_quality_white.csv', delimiter=';')

# %%
# Display the red wine dataset
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Add a color column to identify red wines before concatenation
red_wine_df['color'] = 'red'

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Get a concise summary of the red wine DataFrame
red_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  color                 1599 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %%
# Display the columns of the red wine DataFrame
red_wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
# Display the white wine dataset
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Add a color column to identify white wines before concatenation
white_wine_df['color'] = 'white'

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Get a concise summary of the white wine DataFrame
white_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  color                 4898 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 497.6+ KB

# %%
# Display the columns of the white wine DataFrame
white_wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
# Combine red and white wine DataFrames into one
combined_wine_df = pd.concat([red_wine_df, white_wine_df], ignore_index=True, sort=False)
# Display the combined wine DataFrame
combined_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Sort the combined DataFrame by quality in descending order
combined_wine_df = combined_wine_df.sort_values(by=['quality'], ascending=False)
# Display the combined wine DataFrame
combined_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2475            6.9             0.360         0.34             4.2      0.018
# 3204            7.1             0.260         0.49             2.2      0.032
# 2426            7.4             0.240         0.36             2.0      0.031
# 2373            9.1             0.270         0.45            10.6      0.035
# 2419            6.6             0.360         0.29             1.6      0.021
# ...             ...               ...          ...             ...        ...
# 3649           11.8             0.230         0.38            11.1      0.034
# 1374            6.8             0.815         0.00             1.2      0.267
# 4906            9.4             0.240         0.29             8.5      0.037
# 1299            7.6             1.580         0.00             2.1      0.137
# 1469            7.3             0.980         0.05             2.1      0.061
#
# ...

# %%
# Save the cleaned combined DataFrame to a CSV file
combined_wine_df.to_csv('cleaned_wine_data.csv', index=False)

# %% [markdown]
# Calculate the mean and range of 'fixed acidity' for red wine, then plot the average 'fixed acidity' vs. quality

# %%
red_wine_df['fixed acidity'].mean()
# Out:
# 8.31963727329581

# %%
red_wine_df['fixed acidity'].min()
# Out:
# 4.6

# %%
red_wine_df['fixed acidity'].max()
# Out:
# 15.9

# %%
plt.figure()
red_wine_df.groupby('quality')['fixed acidity'].mean().plot(color='red')
plt.title('Average Fixed Acidity vs. Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Fixed Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'fixed acidity' for white wine, then plot the average 'fixed acidity' vs. quality

# %%
white_wine_df['fixed acidity'].mean()
# Out:
# 6.854787668436097

# %%
white_wine_df['fixed acidity'].min()
# Out:
# 3.8

# %%
white_wine_df['fixed acidity'].max()
# Out:
# 14.2

# %%
plt.figure()
white_wine_df.groupby('quality')['fixed acidity'].mean().plot(color='blue')
plt.title('Average Fixed Acidity vs. White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Fixed Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'fixed acidity' for combined DataFrame, then plot the average 'fixed acidity' vs. quality

# %%
combined_wine_df['fixed acidity'].mean()
# Out:
# 7.215307064799139

# %%
combined_wine_df['fixed acidity'].min()
# Out:
# 3.8

# %%
combined_wine_df['fixed acidity'].max()
# Out:
# 15.9

# %%
plt.figure()
combined_wine_df.groupby('quality')['fixed acidity'].mean().plot(color='purple')
plt.title('Average Fixed Acidity vs. Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Fixed Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'volatile acidity' for red wine, then plot the average 'volatile acidity' vs. quality

# %%
red_wine_df['volatile acidity'].mean()
# Out:
# 0.5278205128205128

# %%
red_wine_df['volatile acidity'].min()
# Out:
# 0.12

# %%
red_wine_df['volatile acidity'].max()
# Out:
# 1.58

# %%
plt.figure()
red_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='red')
plt.title('Average Volatile Acidity vs. Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'volatile acidity' for white wine, then plot the average 'volatile acidity' vs. quality

# %%
white_wine_df['volatile acidity'].mean()
# Out:
# 0.27824111882400976

# %%
white_wine_df['volatile acidity'].min()
# Out:
# 0.08

# %%
white_wine_df['volatile acidity'].max()
# Out:
# 1.1

# %%
plt.figure()
white_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='blue')
plt.title('Average Volatile Acidity vs. White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'volatile acidity' for the combined DataFrame, then plot the average 'volatile acidity' vs. quality

# %%
combined_wine_df['volatile acidity'].mean()
# Out:
# 0.3396659996921656

# %%
combined_wine_df['volatile acidity'].min()
# Out:
# 0.08

# %%
combined_wine_df['volatile acidity'].max()
# Out:
# 1.58

# %%
plt.figure()
combined_wine_df.groupby('quality')['volatile acidity'].mean().plot(color='purple')
plt.title('Average Volatile Acidity vs. Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Volatile Acidity')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'citric acid' for red wine, then create a bar graph showing the average 'citric acid' by quality

# %%
red_wine_df['citric acid'].mean()
# Out:
# 0.2709756097560976

# %%
red_wine_df['citric acid'].min()
# Out:
# 0.0

# %%
red_wine_df['citric acid'].max()
# Out:
# 1.0

# %%
plt.figure()
red_wine_df.groupby('quality')['citric acid'].mean().plot(kind='bar', color='red')
plt.title('Average Citric Acid by Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Citric Acid')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'citric acid' for white wine, then create a bar graph showing the average 'citric acid' by quality

# %%
white_wine_df['citric acid'].mean()
# Out:
# 0.33419150673744386

# %%
white_wine_df['citric acid'].min()
# Out:
# 0.0

# %%
white_wine_df['citric acid'].max()
# Out:
# 1.66

# %%
plt.figure()
white_wine_df.groupby('quality')['citric acid'].mean().plot(kind='bar', color='blue')
plt.title('Average Citric Acid by White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Citric Acid')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'citric acid' for the combined DataFrame, then create a bar graph showing the average 'citric acid' by quality

# %%
combined_wine_df['citric acid'].mean()
# Out:
# 0.3186332153301524

# %%
combined_wine_df['citric acid'].min()
# Out:
# 0.0

# %%
combined_wine_df['citric acid'].max()
# Out:
# 1.66

# %%
plt.figure()
combined_wine_df.groupby('quality')['citric acid'].mean().plot(kind='bar', color='purple')
plt.title('Average Citric Acid by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Citric Acid')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'residual sugar' for red wine, then create a scatter plot showing the 'residual sugar' vs. quality

# %%
red_wine_df['residual sugar'].mean()
# Out:
# 2.53880550343965

# %%
red_wine_df['residual sugar'].min()
# Out:
# 0.9

# %%
red_wine_df['residual sugar'].max()
# Out:
# 15.5

# %%
plt.figure()
plt.scatter(red_wine_df['residual sugar'], red_wine_df['quality'], alpha=0.5, c='red')
plt.title('Residual Sugar vs. Red Wine Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'residual sugar' for white wine, then create a scatter plot showing the 'residual sugar' vs. quality

# %%
white_wine_df['residual sugar'].mean()
# Out:
# 6.391414863209474

# %%
white_wine_df['residual sugar'].min()
# Out:
# 0.6

# %%
white_wine_df['residual sugar'].max()
# Out:
# 65.8

# %%
plt.figure()
plt.scatter(white_wine_df['residual sugar'], white_wine_df['quality'], alpha=0.5, c='blue')
plt.title('Residual Sugar vs. White Wine Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'residual sugar' for the combined DataFrame, then create a scatter plot showing the 'residual sugar' vs. quality

# %%
combined_wine_df['residual sugar'].mean()
# Out:
# 5.44323533938741

# %%
combined_wine_df['residual sugar'].min()
# Out:
# 0.6

# %%
combined_wine_df['residual sugar'].max()
# Out:
# 65.8

# %%
plt.figure()
plt.scatter(combined_wine_df['residual sugar'], combined_wine_df['quality'], alpha=0.5, c='purple')
plt.title('Residual Sugar vs. Wine Quality')
plt.xlabel('Residual Sugar (g/L)')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'chlorides' for red wine, then create a bar graph showing the average 'chlorides' by quality

# %%
red_wine_df['chlorides'].mean()
# Out:
# 0.08746654158849279

# %%
red_wine_df['chlorides'].min()
# Out:
# 0.012

# %%
red_wine_df['chlorides'].max()
# Out:
# 0.611

# %%
plt.figure()
red_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='red')
plt.title('Average Chlorides by Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'chlorides' for white wine, then create a bar graph showing the average 'chlorides' by quality

# %%
white_wine_df['chlorides'].mean()
# Out:
# 0.04577235606369946

# %%
white_wine_df['chlorides'].min()
# Out:
# 0.009

# %%
white_wine_df['chlorides'].max()
# Out:
# 0.346

# %%
plt.figure()
white_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='blue')
plt.title('Average Chlorides by White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'chlorides' for the combined DataFrame, then create a bar graph showing the average 'chlorides' by quality

# %%
combined_wine_df['chlorides'].mean()
# Out:
# 0.05603386178236109

# %%
combined_wine_df['chlorides'].min()
# Out:
# 0.009

# %%
combined_wine_df['chlorides'].max()
# Out:
# 0.611

# %%
plt.figure()
combined_wine_df.groupby('quality')['chlorides'].mean().plot(kind='bar', color='purple')
plt.title('Average Chlorides by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Chlorides')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'density' and 'alcohol' for red wine, then create a scatter plot to show the relationship between 'density' and 'alcohol'

# %%
red_wine_df['density'].mean()
# Out:
# 0.9967466791744841

# %%
red_wine_df['alcohol'].mean()
# Out:
# 10.422983114446529

# %%
red_wine_df['density'].min()
# Out:
# 0.99007

# %%
red_wine_df['alcohol'].min()
# Out:
# 8.4

# %%
red_wine_df['density'].max()
# Out:
# 1.00369

# %%
red_wine_df['alcohol'].max()
# Out:
# 14.9

# %%
plt.figure()
plt.scatter(red_wine_df['density'], red_wine_df['alcohol'], alpha=0.5, c='red')
plt.title('Relationship between Density and Alcohol Content in Red Wine')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'density' and 'alcohol' for white wine, then create a scatter plot to show the relationship between 'density' and 'alcohol'

# %%
white_wine_df['density'].mean()
# Out:
# 0.9940273764801959

# %%
white_wine_df['alcohol'].mean()
# Out:
# 10.514267047774602

# %%
white_wine_df['density'].min()
# Out:
# 0.98711

# %%
white_wine_df['alcohol'].min()
# Out:
# 8.0

# %%
white_wine_df['density'].max()
# Out:
# 1.03898

# %%
white_wine_df['alcohol'].max()
# Out:
# 14.2

# %%
plt.figure()
plt.scatter(white_wine_df['density'], white_wine_df['alcohol'], alpha=0.5, c='blue')
plt.title('Relationship between Density and Alcohol Content in White Wine')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'density' and 'alcohol' for the combined DataFrame, then create a scatter plot to show the relationship between 'density' and 'alcohol'

# %%
combined_wine_df['density'].mean()
# Out:
# 0.9946966338309989

# %%
combined_wine_df['alcohol'].mean()
# Out:
# 10.491800831152839

# %%
combined_wine_df['density'].min()
# Out:
# 0.98711

# %%
combined_wine_df['alcohol'].min()
# Out:
# 8.0

# %%
combined_wine_df['density'].max()
# Out:
# 1.03898

# %%
combined_wine_df['alcohol'].max()
# Out:
# 14.9

# %%
plt.figure()
plt.scatter(combined_wine_df['density'], combined_wine_df['alcohol'], alpha=0.5, c='purple')
plt.title('Relationship between Density and Alcohol Content in Wine')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate the mean and range of 'pH' for red wine, then create a graph to show the distribution of pH content by wine quality

# %%
red_wine_df['pH'].mean()
# Out:
# 3.3111131957473416

# %%
red_wine_df['pH'].min()
# Out:
# 2.74

# %%
red_wine_df['pH'].max()
# Out:
# 4.01

# %%
plt.figure()
for quality in sorted(red_wine_df['quality'].unique()):
    subset = red_wine_df[red_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Red Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'pH' for white wine, then create a graph to show the distribution of pH content by wine quality

# %%
white_wine_df['pH'].mean()
# Out:
# 3.1882666394446715

# %%
white_wine_df['pH'].min()
# Out:
# 2.72

# %%
white_wine_df['pH'].max()
# Out:
# 3.82

# %%
plt.figure()
for quality in sorted(white_wine_df['quality'].unique()):
    subset = white_wine_df[white_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'pH' for the combined DataFrame, then create a graph to show the distribution of pH content by wine quality

# %%
combined_wine_df['pH'].mean()
# Out:
# 3.2185008465445586

# %%
combined_wine_df['pH'].min()
# Out:
# 2.72

# %%
combined_wine_df['pH'].max()
# Out:
# 4.01

# %%
plt.figure()
for quality in sorted(combined_wine_df['quality'].unique()):
    subset = combined_wine_df[combined_wine_df['quality'] == quality]
    plt.hist(subset['pH'], bins=25, alpha=0.4, label=f'Quality {quality}')
plt.title('Distribution of PH Content by Wine Quality')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'sulphates' for red wine, then plot the average 'sulfates' vs. quality

# %%
red_wine_df['sulphates'].mean()
# Out:
# 0.6581488430268917

# %%
red_wine_df['sulphates'].min()
# Out:
# 0.33

# %%
red_wine_df['sulphates'].max()
# Out:
# 2.0

# %%
plt.figure()
red_wine_df.groupby('quality')['sulphates'].mean().plot(color='red')
plt.title('Average Sulphates vs. Red Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'sulphates' for white wine, then plot the average 'sulfates' vs. quality

# %%
white_wine_df['sulphates'].mean()
# Out:
# 0.48984687627603113

# %%
white_wine_df['sulphates'].min()
# Out:
# 0.22

# %%
white_wine_df['sulphates'].max()
# Out:
# 1.08

# %%
plt.figure()
white_wine_df.groupby('quality')['sulphates'].mean().plot(color='blue')
plt.title('Average Sulphates vs. White Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Calculate the mean and range of 'sulphates' for the combined DateFrame, then plot the average 'sulfates' vs. quality

# %%
combined_wine_df['sulphates'].mean()
# Out:
# 0.5312682776666153

# %%
combined_wine_df['sulphates'].min()
# Out:
# 0.22

# %%
combined_wine_df['sulphates'].max()
# Out:
# 2.0

# %%
plt.figure()
combined_wine_df.groupby('quality')['sulphates'].mean().plot(color='purple')
plt.title('Average Sulphates vs. Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Create graphs to show the distribution of alcohol content by wine quality for red wine, white wine, and the combined DataFrame

# %%
plt.figure()
for quality in sorted(red_wine_df['quality'].unique()):
    subset = red_wine_df[red_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by Red Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure()
for quality in sorted(white_wine_df['quality'].unique()):
    subset = white_wine_df[white_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by White Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
plt.figure()
for quality in sorted(combined_wine_df['quality'].unique()):
    subset = combined_wine_df[combined_wine_df['quality'] == quality]
    plt.hist(subset['alcohol'], bins=15, alpha=0.5, label=f'Quality {quality}')
plt.title('Distribution of Alcohol Content by Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.legend(title='Quality Score')
plt.grid(axis='y')
plt.show()

# %%
#Create a box plot of wine quality by wine color
plt.figure()
combined_wine_df.boxplot(column='quality', by='color')
plt.title('Box Plot of Wine Quality by Wine Color')
plt.suptitle('')
plt.xlabel('Wine Color')
plt.ylabel('Quality')
plt.show()
