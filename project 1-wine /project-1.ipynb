# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
red_wine_df = pd.read_csv("wine_quality_red.csv", delimiter=';')
white_wine_df = pd.read_csv("wine_quality_white.csv",  delimiter=';')

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine_df["color"] = "red"

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine_df["color"] ="white"

# %%
white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
print(red_wine_df.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
print(white_wine_df.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
combined_wine_df = pd.concat([red_wine_df, white_wine_df], ignore_index=True, sort=False)
combined_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
combined_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
combined_wine_df.nunique()
# Out:
# fixed acidity           106
# volatile acidity        187
# citric acid              89
# residual sugar          316
# chlorides               214
# free sulfur dioxide     135
# total sulfur dioxide    276
# density                 998
# pH                      108
# sulphates               111
# alcohol                 111
# quality                   7
# color                     2
# dtype: int64

# %%
combined_wine_df.sort_values(by=["quality"],ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2475            6.9             0.360         0.34             4.2      0.018
# 3204            7.1             0.260         0.49             2.2      0.032
# 2426            7.4             0.240         0.36             2.0      0.031
# 2373            9.1             0.270         0.45            10.6      0.035
# 2419            6.6             0.360         0.29             1.6      0.021
# ...             ...               ...          ...             ...        ...
# 3649           11.8             0.230         0.38            11.1      0.034
# 1374            6.8             0.815         0.00             1.2      0.267
# 4906            9.4             0.240         0.29             8.5      0.037
# 1299            7.6             1.580         0.00             2.1      0.137
# 1469            7.3             0.980         0.05             2.1      0.061
#
# ...

# %%
combined_wine_df.head(100)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# ..            ...               ...          ...             ...        ...
# 95            4.7             0.600         0.17             2.3      0.058
# 96            6.8             0.775         0.00             3.0      0.102
# 97            7.0             0.500         0.25             2.0      0.070
# 98            7.6             0.900         0.06             2.5      0.079
# 99            8.1             0.545         0.18             1.9      0.080
#
# ...

# %%
red_wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
df = red_wine_df[["alcohol", "pH"]]
df
# Out:
#       alcohol    pH
# 0         9.4  3.51
# 1         9.8  3.20
# 2         9.8  3.26
# 3         9.8  3.16
# 4         9.4  3.51
# ...       ...   ...
# 1594     10.5  3.45
# 1595     11.2  3.52
# 1596     11.0  3.42
# 1597     10.2  3.57
# 1598     11.0  3.39
#
# [1599 rows x 2 columns]

# %%
def body(x):
    if x <12.5:
        return "pink"
    elif x>13.5:
        return "darkred"
    else: 
        return "crimson"

# %%
body(12.4)
# Out:
# 'pink'

# %%
df
# Out:
#       alcohol    pH
# 0         9.4  3.51
# 1         9.8  3.20
# 2         9.8  3.26
# 3         9.8  3.16
# 4         9.4  3.51
# ...       ...   ...
# 1594     10.5  3.45
# 1595     11.2  3.52
# 1596     11.0  3.42
# 1597     10.2  3.57
# 1598     11.0  3.39
#
# [1599 rows x 2 columns]

# %%
df["Body"] = df["alcohol"].apply(body)
df.head()
# Out:
# /var/folders/1p/5jqrq9_n1n3_2ccv8t2hw9ww0000gn/T/ipykernel_3674/3664870064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Body"] = df["alcohol"].apply(body)
#    alcohol    pH  Body
# 0      9.4  3.51  pink
# 1      9.8  3.20  pink
# 2      9.8  3.26  pink
# 3      9.8  3.16  pink
# 4      9.4  3.51  pink

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x="alcohol", y="pH",c=df["Body"])
plt.title("alcohol vs pH ")
plt.show()

# %%
df_white_wine = white_wine_df[["alcohol", "pH"]]
df_white_wine
# Out:
#       alcohol    pH
# 0         8.8  3.00
# 1         9.5  3.30
# 2        10.1  3.26
# 3         9.9  3.19
# 4         9.9  3.19
# ...       ...   ...
# 4893     11.2  3.27
# 4894      9.6  3.15
# 4895      9.4  2.99
# 4896     12.8  3.34
# 4897     11.8  3.26
#
# [4898 rows x 2 columns]

# %%
def white_wine_body(x):
    if x <12.5:
        return "paleturquoise"
    elif x>13.5:
        return "deepskyblue"
    else: 
        return "darkblue"

# %%
df_white_wine["white_wine_body"] = white_wine_df["alcohol"].apply(white_wine_body)
df_white_wine.head()
# Out:
# /var/folders/1p/5jqrq9_n1n3_2ccv8t2hw9ww0000gn/T/ipykernel_1993/1601703803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_white_wine["white_wine_body"] = white_wine_df["alcohol"].apply(white_wine_body)
#    alcohol    pH white_wine_body
# 0      8.8  3.00   paleturquoise
# 1      9.5  3.30   paleturquoise
# 2     10.1  3.26   paleturquoise
# 3      9.9  3.19   paleturquoise
# 4      9.9  3.19   paleturquoise

# %%
white_wine_body(12.5)
# Out:
# 'darkblue'

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df_white_wine,x="alcohol", y="pH",c=df_white_wine["white_wine_body"])
plt.title("alcohol vs pH ")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(correlation, annot=True,cmap="coolwarm",vmin=-1, vmax=1, center=0 )
plt.title("alcohol vs pH ")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df,x="alcohol", y="pH")
plt.title("alcohol vs pH ")
plt.show()

# %%
condition = x+y>1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 condition = x+y>1
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x="alcohol", y="pH", hue="blue")
plt.title("alcohol vs pH ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 sns.scatterplot(data=df,x="alcohol", y="pH", hue="blue")
#       3 plt.title("alcohol vs pH ")
#       4 plt.show()
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
# ...

# %%
np.random.seed(0)
df = pd.DataFrame({"x": np.random.rand(1599),"y": np.random.rand(1599)})
color =[]
#for index, row in df.iterrows():
    #if row["x"]>row ["y"]:
        #color.append("blue")
    #else :
        #color.append
plt.scatter(df["x"],df["y"], cmap="coolwarm")
plt.xlabel("alcohol")
plt.ylabel("pH")
plt.show()
# Out:
# /var/folders/1p/5jqrq9_n1n3_2ccv8t2hw9ww0000gn/T/ipykernel_1993/3631343310.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(df["x"],df["y"], cmap="coolwarm")

# %%
#alcohol amount in red and white wine 

combined_wine_df

# %%
# create data 
x = [10,20,30,40,50] 
y = [30,30,30,30,30] 
  
# plot lines 
plt.plot(x, y, label = "line 1") 
plt.plot(y, x, label = "line 2") 
plt.legend() 
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=red_wine_df,x="alcohol", y="residual sugar")
plt.title("alcohol vs residual sugar ")
plt.show()
