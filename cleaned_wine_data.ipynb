# %%
import pandas as pd

# %%
red_wine_df = pd.read_csv(r"C:\Users\rasha\Group4\Group4\Wine-Quality-Analysis\winequality-red.csv", delimiter=";")
white_wine_df = pd.read_csv(r"C:\Users\rasha\Group4\Group4\Wine-Quality-Analysis\winequality-white.csv", delimiter=";")

# %%
#concatenate the two dataframes
wine_df = pd.concat([red_wine_df, white_wine_df], ignore_index=True)
#save the concatenated dataframe to a csv file
wine_df.to_csv("C:\\Users\\rasha\\Group4\\winequality.csv", index=False)
#read the concatenated dataframe from the csv file
wine_df = pd.read_csv("C:\\Users\\rasha\\Group4\\winequality.csv")

# %%
import matplotlib.pyplot as plt

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Red Wine Exploration

# %%
red_wine_df.groupby('quality')[["sulphates"]].mean().plot(kind='line',color="green",figsize=(12, 4),fontsize=10)
plt.title('Average Sulphates by Red Wine Quality')
plt.xlabel('Wine Quality')
plt.legend(fontsize = 12)
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### The above visualization helps in understanding how sulphates levels correlate with the quality of red wines. By analyzing the plot, we can identify trends and patterns that might indicate the impact of sulphates on wine quality.

# %%
red_wine_df['quality'].value_counts().sort_index().plot(kind='pie',autopct='%1.1f%%',cmap="RdYlGn",figsize=(12,12),fontsize=18)
plt.title('Red Wines Percentage of Volume Distribution Based on Quality Ranking')
plt.legend(title='Wine Quality',fontsize=15 )
plt.grid(axis='y')
plt.style.use("grayscale")
plt.show()

# %% [markdown]
# ##### The above visualization provides a clear picture of the distribution of red wine quality within the dataset. By examining the pie chart and the quantifiable data, we can determine which quality levels are more prevalent and understand the overall quality distribution of the red wines.

# %% [markdown]
# ### White Wine Exploration

# %%
white_wine_df.groupby('quality')[["sulphates"]].mean().plot(kind='line',color="blue",figsize=(12, 4),fontsize=10)
plt.title('Average Sulphates by White Wine Quality')
plt.xlabel('Wine Quality')
plt.legend(fontsize = 12)
plt.ylabel('Sulphates')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### The above visualization helps in understanding how sulphates levels correlate with the quality of white wines. By analyzing the plot and the quantifiable data, we can identify trends and patterns that might indicate the impact of sulphates on wine quality.

# %%
white_wine_df['quality'].value_counts().sort_index().plot(kind='pie',autopct='%1.1f%%',cmap="RdYlGn",figsize=(12,12),fontsize=18)
plt.title('White Wines Percentage of Volume Distribution based on Quality Ranking')
plt.legend(title='Wine Quality',fontsize=10 )
plt.style.use("grayscale")
#plt.style.use("dark_background")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### The above visualization provides a clear picture of the distribution of white wine quality within the dataset. By examining the pie chart and the quantifiable data, we can determine which quality levels are more prevalent and understand the overall quality distribution of the white wines.
